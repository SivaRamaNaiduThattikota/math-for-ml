# %% [markdown]
# # Matrices as transformations — practice
#
# Read `theory.html` first. Predict each result **geometrically** before running.

# %%
import numpy as np

A = np.array([[2., 1.], [0., 3.]])
x = np.array([1., 1.])
print("A @ x      =", A @ x)                 # apply transformation
print("det A      =", np.linalg.det(A))
print("col 1 (Ai) =", A @ np.array([1, 0]))  # image of i-hat
print("col 2 (Aj) =", A @ np.array([0, 1]))  # image of j-hat

# %% [markdown]
# ### E1 (easy) — scaling
# Apply `[[3,0],[0,1]]` to `[2,5]`. Describe the transformation in words.

# %%
# E1

# %% [markdown]
# ### E2 (easy) — read the basis images
# Where do i-hat and j-hat land under `[[1,1],[0,1]]`? What transformation is it?

# %%
# E2

# %% [markdown]
# ### E3 (medium) — build a 90 rotation
# Make the matrix that rotates 90 counter-clockwise; verify it sends [1,0] to [0,1].

# %%
# E3

# %% [markdown]
# ### E4 (medium) — singular matrix
# Compute det of [[2,1],[4,2]]. What does the value mean geometrically?

# %%
# E4

# %% [markdown]
# ### E5 (hard) — idempotent projection
# P = [[1,0],[0,0]]. Show P @ P == P and explain why (projection applied twice = once).

# %%
# E5
