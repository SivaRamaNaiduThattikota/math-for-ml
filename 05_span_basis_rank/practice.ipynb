# %% [markdown]
# # Span, basis, rank & independence — practice
#
# Read `theory.html` first. Reason geometrically, then check with `np.linalg.matrix_rank`.

# %%
import numpy as np

indep = np.array([[1., 0.], [0., 1.]])   # independent columns
dep   = np.array([[1., 2.], [2., 4.]])   # col2 = 2*col1
print("rank indep =", np.linalg.matrix_rank(indep))
print("rank dep   =", np.linalg.matrix_rank(dep), " det dep =", np.linalg.det(dep))

# %% [markdown]
# ### E1 (easy) — independence by rank
# Are [1,2] & [2,4] independent? [1,2] & [2,1]? Check rank of each pair (as columns).

# %%
# E1

# %% [markdown]
# ### E2 (easy) — 3 vectors in R^2
# Can 3 vectors in R^2 be independent? Explain (max independent set = dimension).

# %%
# E2 (written answer + optional check)

# %% [markdown]
# ### E3 (medium) — engineered dependence
# Make a 3x3 matrix whose 3rd column = col1 + col2. Predict rank & det, then verify.

# %%
# E3

# %% [markdown]
# ### E4 (medium) — dummy variable trap
# One-hot 3 categories + a column of ones (intercept). Show the matrix is rank-deficient.

# %%
# E4

# %% [markdown]
# ### E5 (hard) — keep vs break independence
# Given [1,1,0] and [0,1,1], find a 3rd vector that (a) keeps rank 3, (b) keeps rank 2.

# %%
# E5
