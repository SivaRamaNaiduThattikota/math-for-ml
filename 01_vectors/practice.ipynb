# %% [markdown]
# # Vectors — practice (NumPy re-derivation)
#
# Read `theory.html` first, then work the exercises here. Retype, run, break, fix — mistakes are the point.
# Verify every result against what you computed by hand.

# %%
import numpy as np

a = np.array([4, 2])
b = np.array([1, 3])
print("a + b =", a + b)
print("2a    =", 2 * a)
print("|a|   =", np.linalg.norm(a))

# %% [markdown]
# ### E1 (easy) — addition / scalar / subtraction
# `a=[2,-1,4]`, `b=[0,3,1]`. Compute `a+b`, `3a`, `a-b` by hand first, then verify below.

# %%
# E1

# %% [markdown]
# ### E2 (easy) — magnitude
# Compute `‖[6,8]‖` by hand (clean integer), then confirm with `np.linalg.norm`.

# %%
# E2

# %% [markdown]
# ### E3 (medium) — safe normalize
# Write `unit(v)` that normalizes, but returns the zero vector unchanged instead of `nan`.

# %%
# E3
def unit(v):
    pass

# %% [markdown]
# ### E4 (medium) — feature scaling in one exercise
# Houses `[1200,3]` and `[1400,2]`: Euclidean distance. Then divide sqft by 1000 and recompute. Why did it change?

# %%
# E4

# %% [markdown]
# ### E5 (hard) — magnitude via dot product
# Without `np.linalg.norm`, compute the magnitude of a length-1000 random vector using only `np.dot`.
# Hint: ‖v‖ = sqrt(v · v).

# %%
# E5
