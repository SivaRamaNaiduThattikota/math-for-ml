# %% [markdown]
# # Inference & hypothesis testing — practice
#
# Read `theory.html` first. p-value = P(data this extreme | H0).

# %%
import numpy as np
from math import erf, sqrt
Phi = lambda z: 0.5*(1 + erf(z/sqrt(2)))

# A/B two-proportion z-test
nA=nB=2000; cA,cB=200,240
pA,pB=cA/nA,cB/nB; p=(cA+cB)/(nA+nB)
se=sqrt(p*(1-p)*(1/nA+1/nB)); z=(pB-pA)/se; pval=2*(1-Phi(abs(z)))
print('lift',round(pB-pA,3),'z',round(z,2),'p',round(pval,4))

# %% [markdown]
# ### E1 (easy) — confidence interval
# n=400, mean=50, std=10. 95% CI for the mean?

# %%
# E1

# %% [markdown]
# ### E2 (easy) — A/B z & p
# A=200/2000, B=240/2000. Lift, z, p-value.

# %%
# E2

# %% [markdown]
# ### E3 (medium) — two-sided p from CDF
# Write the p-value function and reproduce E2.

# %%
# E3

# %% [markdown]
# ### E4 (medium) — false positive rate
# 10,000 A/B tests with NO true effect (pA=pB=0.1, n=1000). Fraction with p<0.05? (~5%)

# %%
# E4

# %% [markdown]
# ### E5 (hard) — power vs n
# pA=0.10, pB=0.12. Estimate power (fraction significant) at n=1000 vs n=5000 by simulation.

# %%
# E5
